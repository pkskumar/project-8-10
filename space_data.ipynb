# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
#reading csv file of dataset
df=pd.read_csv('space_server.csv')
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# 0     15.50342  15.22531   752    301       4    267  3.722360e+18    STAR
# 1     16.48922  16.39150   752    301       4    267  3.638140e+17    STAR
# 2     17.08732  16.80125   752    301       4    268  3.232740e+17  GALAXY
# 3     15.98233  15.90438   752    301       4    269  3.722370e+18    STAR
# 4     16.55492  16.61326   752    301       4    269  3.722370e+18    STAR
# ...        ...       ...   ...    ...     ...    ...           ...     ...
# 9995  16.68305  16.50570  1345    301       3    161  5.033450e+17  GALAXY
# 9996  16.71661  16.69897  1345    301       3    162  5.033400e+17  GALAXY
# 9997  17.43302  17.42048  1345    301       3    162  8.222620e+18    STAR
# 9998  17.36284  17.13988  1345    301       3    163  5.033400e+17  GALAXY
# 9999  15.83548  15.50588  1345    301       3    163  5.033410e+17  GALAXY
#
#       redshift  plate    mjd  fiberid
# 0    -0.000009   3306  54922      491
# 1    -0.000055    323  51615      541
# 2     0.123111    287  52023      513
# 3    -0.000111   3306  54922      510
# 4     0.000590   3306  54922      512
# ...        ...    ...    ...      ...
# 9995  0.027583    447  51877      246
# 9996  0.117772    447  51877      228
# 9997 -0.000402   7303  57013      622
# 9998  0.014019    447  51877      229
# 9999  0.118417    447  51877      233
#
# [10000 rows x 18 columns]

# %%
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# 0  54922      491
# 1  51615      541
# 2  52023      513
# 3  54922      510
# 4  54922      512

# %%
df.tail()
# Out:
#              objid          ra        dec         u         g         r  \
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# 9995  16.68305  16.50570  1345    301       3    161  5.033450e+17  GALAXY
# 9996  16.71661  16.69897  1345    301       3    162  5.033400e+17  GALAXY
# 9997  17.43302  17.42048  1345    301       3    162  8.222620e+18    STAR
# 9998  17.36284  17.13988  1345    301       3    163  5.033400e+17  GALAXY
# 9999  15.83548  15.50588  1345    301       3    163  5.033410e+17  GALAXY
#
#       redshift  plate    mjd  fiberid
# 9995  0.027583    447  51877      246
# 9996  0.117772    447  51877      228
# 9997 -0.000402   7303  57013      622
# 9998  0.014019    447  51877      229
# 9999  0.118417    447  51877      233

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 1.4+ MB

# %%
df=df.replace(0,np.nan)
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# 0     15.50342  15.22531   752    301       4    267  3.722360e+18    STAR
# 1     16.48922  16.39150   752    301       4    267  3.638140e+17    STAR
# 2     17.08732  16.80125   752    301       4    268  3.232740e+17  GALAXY
# 3     15.98233  15.90438   752    301       4    269  3.722370e+18    STAR
# 4     16.55492  16.61326   752    301       4    269  3.722370e+18    STAR
# ...        ...       ...   ...    ...     ...    ...           ...     ...
# 9995  16.68305  16.50570  1345    301       3    161  5.033450e+17  GALAXY
# 9996  16.71661  16.69897  1345    301       3    162  5.033400e+17  GALAXY
# 9997  17.43302  17.42048  1345    301       3    162  8.222620e+18    STAR
# 9998  17.36284  17.13988  1345    301       3    163  5.033400e+17  GALAXY
# 9999  15.83548  15.50588  1345    301       3    163  5.033410e+17  GALAXY
#
#       redshift  plate    mjd  fiberid
# 0    -0.000009   3306  54922      491
# 1    -0.000055    323  51615      541
# 2     0.123111    287  52023      513
# 3    -0.000111   3306  54922      510
# 4     0.000590   3306  54922      512
# ...        ...    ...    ...      ...
# 9995  0.027583    447  51877      246
# 9996  0.117772    447  51877      228
# 9997 -0.000402   7303  57013      622
# 9998  0.014019    447  51877      229
# 9999  0.118417    447  51877      233
#
# [10000 rows x 18 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   9981 non-null   float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 1.4+ MB

# %%
df=df.fillna(df.mean())

# %%
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# 0     15.50342  15.22531   752    301       4    267  3.722360e+18    STAR
# 1     16.48922  16.39150   752    301       4    267  3.638140e+17    STAR
# 2     17.08732  16.80125   752    301       4    268  3.232740e+17  GALAXY
# 3     15.98233  15.90438   752    301       4    269  3.722370e+18    STAR
# 4     16.55492  16.61326   752    301       4    269  3.722370e+18    STAR
# ...        ...       ...   ...    ...     ...    ...           ...     ...
# 9995  16.68305  16.50570  1345    301       3    161  5.033450e+17  GALAXY
# 9996  16.71661  16.69897  1345    301       3    162  5.033400e+17  GALAXY
# 9997  17.43302  17.42048  1345    301       3    162  8.222620e+18    STAR
# 9998  17.36284  17.13988  1345    301       3    163  5.033400e+17  GALAXY
# 9999  15.83548  15.50588  1345    301       3    163  5.033410e+17  GALAXY
#
#       redshift  plate    mjd  fiberid
# 0    -0.000009   3306  54922      491
# 1    -0.000055    323  51615      541
# 2     0.123111    287  52023      513
# 3    -0.000111   3306  54922      510
# 4     0.000590   3306  54922      512
# ...        ...    ...    ...      ...
# 9995  0.027583    447  51877      246
# 9996  0.117772    447  51877      228
# 9997 -0.000402   7303  57013      622
# 9998  0.014019    447  51877      229
# 9999  0.118417    447  51877      233
#
# [10000 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    1.577039e+05     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# std        1.067764      1.141805      1.203188    273.305024      0.0
# min       12.431600     11.947210     11.610410    308.000000    301.0
# 25%       16.173333     15.853705     15.618285    752.000000    301.0
# 50%       16.858770     16.554985     16.389945    756.000000    301.0
# 75%       17.512675     17.258550     17.141447   1331.000000    301.0
# max       24.802040     28.179630     22.833060   1412.000000    301.0
#
#              camcol         field     specobjid      redshift         plate  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       3.648700    302.380100  1.645022e+18      0.143999   1460.986400
# std        1.666183    162.577763  2.013998e+18      0.388723   1788.778371
# min        1.000000     11.000000  2.995780e+17     -0.004136    266.000000
# 25%        2.000000    184.000000  3.389248e+17      0.000084    301.000000
# 50%        4.000000    299.000000  4.966580e+17      0.043223    441.000000
# 75%        5.000000    414.000000  2.881300e+18      0.093093   2559.000000
# max        6.000000    768.000000  9.468830e+18      5.353854   8410.000000
#
#                 mjd       fiberid
# count  10000.000000  10000.000000
# mean   52943.533300    353.069400
# std     1511.150651    206.298149
# min    51578.000000      1.000000
# 25%    51900.000000    186.750000
# 50%    51997.000000    351.000000
# 75%    54468.000000    510.000000
# max    57481.000000   1000.000000

# %%
df.drop('objid',axis=1,inplace=True)

# %%
df.drop('rerun',axis=1,inplace=True)

# %%
df
# Out:
#               ra        dec         u         g         r         i         z  \
# 0     183.531326   0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1     183.598371   0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2     183.680207   0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3     183.870529   0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4     183.883288   0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# ...          ...        ...       ...       ...       ...       ...       ...
# 9995  131.316413  51.539547  18.81777  17.47053  16.91508  16.68305  16.50570
# 9996  131.306083  51.671341  18.27255  17.43849  17.07692  16.71661  16.69897
# 9997  131.552562  51.666986  18.75818  17.77784  17.51872  17.43302  17.42048
# 9998  131.477151  51.753068  18.88287  17.91068  17.53152  17.36284  17.13988
# 9999  131.665012  51.805307  19.27586  17.37829  16.30542  15.83548  15.50588
#
#        run  camcol  field     specobjid   class  redshift  plate    mjd  \
# 0      752       4    267  3.722360e+18    STAR -0.000009   3306  54922
# 1      752       4    267  3.638140e+17    STAR -0.000055    323  51615
# 2      752       4    268  3.232740e+17  GALAXY  0.123111    287  52023
# 3      752       4    269  3.722370e+18    STAR -0.000111   3306  54922
# 4      752       4    269  3.722370e+18    STAR  0.000590   3306  54922
# ...    ...     ...    ...           ...     ...       ...    ...    ...
# 9995  1345       3    161  5.033450e+17  GALAXY  0.027583    447  51877
# 9996  1345       3    162  5.033400e+17  GALAXY  0.117772    447  51877
# 9997  1345       3    162  8.222620e+18    STAR -0.000402   7303  57013
# 9998  1345       3    163  5.033400e+17  GALAXY  0.014019    447  51877
# 9999  1345       3    163  5.033410e+17  GALAXY  0.118417    447  51877
#
#       fiberid
# 0         491
# 1         541
# 2         513
# 3         510
# 4         512
# ...       ...
# 9995      246
# 9996      228
# 9997      622
# 9998      229
# 9999      233
#
# [10000 rows x 16 columns]

# %%
df.corr()
# Out:
#                  ra       dec         u         g         r         i  \
# ra         1.000000  0.003596  0.031238  0.043909  0.047103  0.045731
# dec        0.003596  1.000000  0.035279  0.061875  0.063404  0.058292
# u          0.031238  0.035279  1.000000  0.849232  0.692379  0.602630
# g          0.043909  0.061875  0.849232  1.000000  0.958106  0.907419
# r          0.047103  0.063404  0.692379  0.958106  1.000000  0.977672
# i          0.045731  0.058292  0.602630  0.907419  0.977672  1.000000
# z          0.042950  0.056870  0.551483  0.879622  0.969197  0.981507
# run       -0.092741  0.778385  0.038229  0.058446  0.057261  0.049765
# camcol    -0.006294  0.114614  0.009945  0.010223  0.010747  0.013461
# field      0.594700 -0.131471  0.008548  0.014651  0.017133  0.019781
# specobjid -0.095327  0.088345 -0.129429 -0.054979  0.019788  0.072960
# redshift   0.030410  0.066902  0.163685  0.407440  0.440960  0.431379
# plate     -0.095329  0.088342 -0.129430 -0.054981  0.019787  0.072958
# mjd       -0.086887  0.066147 -0.168793 -0.092772 -0.009345  0.050896
# fiberid    0.057485  0.155012  0.011301  0.047187  0.061081  0.069977
#
#                   z       run    camcol     field  specobjid  redshift  \
# ra         0.042950 -0.092741 -0.006294  0.594700  -0.095327  0.030410
# dec        0.056870  0.778385  0.114614 -0.131471   0.088345  0.066902
# u          0.551483  0.038229  0.009945  0.008548  -0.129429  0.163685
# g          0.879622  0.058446  0.010223  0.014651  -0.054979  0.407440
# r          0.969197  0.057261  0.010747  0.017133   0.019788  0.440960
# i          0.981507  0.049765  0.013461  0.019781   0.072960  0.431379
# z          1.000000  0.048252  0.010930  0.018248   0.112398  0.423991
# run        0.048252  1.000000  0.151814 -0.463898   0.093604  0.058865
# camcol     0.010930  0.151814  1.000000 -0.067921   0.040809  0.006583
# field      0.018248 -0.463898 -0.067921  1.000000  -0.093724  0.015471
# specobjid  0.112398  0.093604  0.040809 -0.093724   1.000000 -0.037749
# redshift   0.423991  0.058865  0.006583  0.015471  -0.037749  1.000000
# plate      0.112397  0.093601  0.040795 -0.093723   1.000000 -0.037750
# mjd        0.095658  0.070354  0.026284 -0.086558   0.966880 -0.057487
# fiberid    0.067980  0.138566  0.535629 -0.040493   0.229837  0.046421
#
#               plate       mjd   fiberid
# ra        -0.095329 -0.086887  0.057485
# dec        0.088342  0.066147  0.155012
# u         -0.129430 -0.168793  0.011301
# g         -0.054981 -0.092772  0.047187
# r          0.019787 -0.009345  0.061081
# i          0.072958  0.050896  0.069977
# z          0.112397  0.095658  0.067980
# run        0.093601  0.070354  0.138566
# camcol     0.040795  0.026284  0.535629
# field     -0.093723 -0.086558 -0.040493
# specobjid  1.000000  0.966880  0.229837
# redshift  -0.037750 -0.057487  0.046421
# plate      1.000000  0.966881  0.229811
# mjd        0.966881  1.000000  0.190328
# fiberid    0.229811  0.190328  1.000000

# %%
sns.pairplot(df)

# %%
#boxplot of columns
col=['ra','dec','u','g','r','i','z','run','camcol','field','specobjid','redshift','plate','mjd','fiberid']
nrow=20
ncol=10
plt.figure(figsize=(20,80))
for i in range(0,len(col)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[col[i]],orient='v')
    plt.tight_layout()

# %%
#checkung distribution bt distplot function
df3=df.drop('class',axis=1)
for j in df3.columns:
    sns.distplot(df[j])
    plt.show()

# %%
#checking skewness of dataset
df.skew()
# Out:
# ra          -1.227350
# dec          1.191544
# u           -1.219795
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# camcol      -0.100220
# field        0.249795
# specobjid    1.794627
# redshift     4.265379
# plate        1.794609
# mjd          1.039610
# fiberid      0.308053
# dtype: float64

# %%
if df['redshift'].skew()>0.55:
    df['redshift']=np.log1p(df['redshift'])

# %%
#checking skewness of dataset
df.skew()
# Out:
# ra          -1.227350
# dec          1.191544
# u           -1.219795
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# camcol      -0.100220
# field        0.249795
# specobjid    1.794627
# redshift     3.512455
# plate        1.794609
# mjd          1.039610
# fiberid      0.308053
# dtype: float64

# %%
#changing categorical data from string to integer
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['class']=le.fit_transform(df['class'].astype(str))

# %%
df
# Out:
#               ra        dec         u         g         r         i         z  \
# 0     183.531326   0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1     183.598371   0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2     183.680207   0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3     183.870529   0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4     183.883288   0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# ...          ...        ...       ...       ...       ...       ...       ...
# 9995  131.316413  51.539547  18.81777  17.47053  16.91508  16.68305  16.50570
# 9996  131.306083  51.671341  18.27255  17.43849  17.07692  16.71661  16.69897
# 9997  131.552562  51.666986  18.75818  17.77784  17.51872  17.43302  17.42048
# 9998  131.477151  51.753068  18.88287  17.91068  17.53152  17.36284  17.13988
# 9999  131.665012  51.805307  19.27586  17.37829  16.30542  15.83548  15.50588
#
#        run  camcol  field     specobjid  class  redshift  plate    mjd  \
# 0      752       4    267  3.722360e+18      2 -0.000009   3306  54922
# 1      752       4    267  3.638140e+17      2 -0.000055    323  51615
# 2      752       4    268  3.232740e+17      0  0.116103    287  52023
# 3      752       4    269  3.722370e+18      2 -0.000111   3306  54922
# 4      752       4    269  3.722370e+18      2  0.000590   3306  54922
# ...    ...     ...    ...           ...    ...       ...    ...    ...
# 9995  1345       3    161  5.033450e+17      0  0.027209    447  51877
# 9996  1345       3    162  5.033400e+17      0  0.111338    447  51877
# 9997  1345       3    162  8.222620e+18      2 -0.000402   7303  57013
# 9998  1345       3    163  5.033400e+17      0  0.013922    447  51877
# 9999  1345       3    163  5.033410e+17      0  0.111915    447  51877
#
#       fiberid
# 0         491
# 1         541
# 2         513
# 3         510
# 4         512
# ...       ...
# 9995      246
# 9996      228
# 9997      622
# 9998      229
# 9999      233
#
# [10000 rows x 16 columns]

# %%
#checking outliers
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
z
# Out:
# array([[0.16745842, 0.58492272, 1.03148637, ..., 1.03148936, 1.30931064,
#         0.66863177],
#        [0.16886159, 0.58311429, 0.05243046, ..., 0.63621258, 0.87919741,
#         0.91101156],
#        [0.17057433, 0.58347525, 0.92156796, ..., 0.65633905, 0.60919097,
#         0.77527888],
#        ...,
#        [0.92039468, 1.46090664, 0.16753826, ..., 3.26608697, 2.69309363,
#         1.3036668 ],
#        [0.92197294, 1.46432109, 0.31801835, ..., 0.56688806, 0.70581092,
#         0.60143828],
#        [0.91804124, 1.46639319, 0.79229193, ..., 0.56688806, 0.70581092,
#         0.5820479 ]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  17,   45,  109, ..., 9994, 9997, 9997], dtype=int64), array([12, 12, 12, ..., 13, 10, 13], dtype=int64))

# %%
#new datset without outliers
df1=df[(z<3).all(axis=1)]
df1
# Out:
#               ra        dec         u         g         r         i         z  \
# 0     183.531326   0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1     183.598371   0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2     183.680207   0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3     183.870529   0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4     183.883288   0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# ...          ...        ...       ...       ...       ...       ...       ...
# 9993  131.398915  51.533706  17.79613  16.02621  15.15955  14.71488  14.33840
# 9995  131.316413  51.539547  18.81777  17.47053  16.91508  16.68305  16.50570
# 9996  131.306083  51.671341  18.27255  17.43849  17.07692  16.71661  16.69897
# 9998  131.477151  51.753068  18.88287  17.91068  17.53152  17.36284  17.13988
# 9999  131.665012  51.805307  19.27586  17.37829  16.30542  15.83548  15.50588
#
#        run  camcol  field     specobjid  class  redshift  plate    mjd  \
# 0      752       4    267  3.722360e+18      2 -0.000009   3306  54922
# 1      752       4    267  3.638140e+17      2 -0.000055    323  51615
# 2      752       4    268  3.232740e+17      0  0.116103    287  52023
# 3      752       4    269  3.722370e+18      2 -0.000111   3306  54922
# 4      752       4    269  3.722370e+18      2  0.000590   3306  54922
# ...    ...     ...    ...           ...    ...       ...    ...    ...
# 9993  1345       3    161  5.033460e+17      0  0.054029    447  51877
# 9995  1345       3    161  5.033450e+17      0  0.027209    447  51877
# 9996  1345       3    162  5.033400e+17      0  0.111338    447  51877
# 9998  1345       3    163  5.033400e+17      0  0.013922    447  51877
# 9999  1345       3    163  5.033410e+17      0  0.111915    447  51877
#
#       fiberid
# 0         491
# 1         541
# 2         513
# 3         510
# 4         512
# ...       ...
# 9993      249
# 9995      246
# 9996      228
# 9998      229
# 9999      233
#
# [8635 rows x 16 columns]

# %%
#shape of new dataset
print(df1.shape)
# Out:
# (8635, 16)

# %%
print(df.shape)
# Out:
# (10000, 16)

# %%
#splitting of data
dfx=df1.drop(columns=['class'])

# %%
dfx.shape
# Out:
# (8635, 15)

# %%
y=pd.DataFrame(df1['class'])

# %%
y.shape
# Out:
# (8635, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
#scaling os x data
x=sc.fit_transform(dfx)
x=pd.DataFrame(x,columns=dfx.columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
print(x_train.shape,'\t',x_test.shape,'\t',y_train.shape,'\t',y_test.shape)
# Out:
# (6908, 15) 	 (1727, 15) 	 (6908, 1) 	 (1727, 1)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

# %%
#checking for best model
model=[SVC(),DecisionTreeClassifier(),KNeighborsClassifier()]
for m in model:
    m.fit(x_train,y_train)
    print('score of ',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('\n')
    print('Error:-')
    print('\n')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('-----------------------------------------------------------------------------------------')
    print('\n')
# Out:
# score of  SVC() is: 0.9810364794441228
#
#
# Error:-
#
#
# 0.9803126809496236
# [[968   4  21]
#  [  7  60   1]
#  [  1   0 665]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       993
#            1       0.94      0.88      0.91        68
#            2       0.97      1.00      0.98       666
#
#     accuracy                           0.98      1727
#    macro avg       0.97      0.95      0.96      1727
# weighted avg       0.98      0.98      0.98      1727
#
# -----------------------------------------------------------------------------------------
#
#
# score of  DecisionTreeClassifier() is: 1.0
#
#
# Error:-
#
#
# 0.9855240301100173
# [[978  14   1]
#  [  8  60   0]
#  [  2   0 664]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       993
#            1       0.81      0.88      0.85        68
#            2       1.00      1.00      1.00       666
#
#     accuracy                           0.99      1727
#    macro avg       0.93      0.95      0.94      1727
# weighted avg       0.99      0.99      0.99      1727
#
# -----------------------------------------------------------------------------------------
#
#
# score of  KNeighborsClassifier() is: 0.9503474232773595
#
#
# Error:-
#
#
# 0.9386218876664737
# [[952   4  37]
#  [ 11  56   1]
#  [ 53   0 613]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       993
#            1       0.93      0.82      0.87        68
#            2       0.94      0.92      0.93       666
#
#     accuracy                           0.94      1727
#    macro avg       0.94      0.90      0.92      1727
# weighted avg       0.94      0.94      0.94      1727
#
# -----------------------------------------------------------------------------------------

# %%
#best model
from sklearn.tree import DecisionTreeClassifier
model=[DecisionTreeClassifier()]
for m in model:
    m.fit(x_train,y_train)
    print('score of ',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('\n')
    print('Error:-')
    print('\n')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('-----------------------------------------------------------------------------------------')
    print('\n')
# Out:
# score of  DecisionTreeClassifier() is: 1.0
#
#
# Error:-
#
#
# 0.984944991314418
# [[978  14   1]
#  [  7  61   0]
#  [  4   0 662]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       993
#            1       0.81      0.90      0.85        68
#            2       1.00      0.99      1.00       666
#
#     accuracy                           0.98      1727
#    macro avg       0.93      0.96      0.95      1727
# weighted avg       0.99      0.98      0.99      1727
#
# -----------------------------------------------------------------------------------------

# %%
cm=confusion_matrix(y_test,predm)
sns.heatmap(cm,annot=True,cbar=False,cmap='Blues')
plt.title('confusion matrix of gradient boost classifier')
plt.show()

# %%
#saving model of dataset where region is target
from joblib import dump
dump(model, 'space_data.joblib')
# Out:
# ['space_data.joblib']
